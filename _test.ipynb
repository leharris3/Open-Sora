# %%
import pandas as pd

df = pd.read_csv("/mnt/mir/fan23j/Open-Sora/data/bball/output_filtered.csv")

# %%
df
# Out:
#                                                     path  \
# 0          17640/period3/17640_period3_2-_77115173_0.mp4
# 1        17640/period3/17640_period3_Foul_77115215_0.mp4
# 2          17640/period3/17640_period3_3+_77115326_0.mp4
# 3      17640/period3/17640_period3_Turnover_93270192_...
# 4      17640/period3/17640_period3_Turnover_77115240_...
# ...                                                  ...
# 32346      17716/period1/17716_period1_2-_76421928_0.mp4
# 32347      17716/period1/17716_period1_2-_76421971_0.mp4
# 32348   17716/period1/17716_period1_Steal_76421875_0.mp4
# 32349      17716/period1/17716_period1_1+_76421903_0.mp4
# 32350      17716/period1/17716_period1_1+_76421883_0.mp4
#
#                                                 text  num_frames  height  \
# 0       A basketball player missing a two-point shot         303     720
# 1              A basketball player committing a foul         229     720
# ...
